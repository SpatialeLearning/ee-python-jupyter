# %% [markdown]
# ### Install the Earth Engine Python API

# %% [markdown]
# ##### Sign up for an Earth Engine account if you do not have one yet.
#
# https://signup.earthengine.google.com
#
# ##### Download Anaconda or Miniconda
#
# Anaconda:
#
# https://www.anaconda.com/
#
# Miniconda:
#
# https://docs.conda.io/en/latest/miniconda.html
#
# ##### Set up a conda environment
#
# conda create -n gee python=3.8
#
# conda activate gee
#
#
# Google Earth Engine
# https://earthengine.google.com/

# %%
# !pip install geemap
# Out:
# Requirement already satisfied: geemap in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (0.16.4)
# Requirement already satisfied: earthengine-api>=0.1.304 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.1.319)
# Requirement already satisfied: geeadd>=0.5.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.5.5)
# Requirement already satisfied: scooby in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: sankee>=0.1.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.2.0)
# Requirement already satisfied: jupyterlab>=3 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (3.4.5)
# Requirement already satisfied: ipyevents in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (2.0.1)
# Requirement already satisfied: whiteboxgui>=0.6.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.7.0)
# Requirement already satisfied: python-box in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (6.0.2)
# Requirement already satisfied: pillow in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (9.2.0)
# Requirement already satisfied: pandas in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (1.4.3)
# Requirement already satisfied: numpy in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (1.22.3)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.17.0)
# Requirement already satisfied: ffmpeg-python in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.2.0)
# Requirement already satisfied: xyzservices in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (2022.6.0)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: matplotlib in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (3.5.1)
# Requirement already satisfied: ee-extra>=0.0.10 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.0.14)
# Requirement already satisfied: ipytree in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.2.1)
# Requirement already satisfied: folium>=0.11.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.12.1.post1)
# Requirement already satisfied: geocoder in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: geojson in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (2.5.0)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (2.1.3)
# Requirement already satisfied: pycrs in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (1.0.2)
# Requirement already satisfied: gdown in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (4.5.1)
# Requirement already satisfied: bqplot in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.12.33)
# Requirement already satisfied: colour in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: google-cloud-storage in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (2.5.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.20.4)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (1.12.11)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.1.0)
# Requirement already satisfied: six in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (1.16.0)
# Requirement already satisfied: httplib2shim in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.0.3)
# Requirement already satisfied: future in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (0.18.2)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from earthengine-api>=0.1.304->geemap) (2.10.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from folium>=0.11.0->geemap) (3.0.3)
# Requirement already satisfied: requests in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from folium>=0.11.0->geemap) (2.28.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from folium>=0.11.0->geemap) (0.5.0)
# Requirement already satisfied: logzero>=1.5.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geeadd>=0.5.1->geemap) (4.11.1)
# Requirement already satisfied: ipywidgets in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (7.7.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: jupyter-core in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (4.10.0)
# Requirement already satisfied: nbclassic in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (0.4.3)
# Requirement already satisfied: packaging in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (21.3)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (6.1)
# Requirement already satisfied: notebook<7 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (6.4.11)
# Requirement already satisfied: jupyter-server~=1.16 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (1.18.1)
# Requirement already satisfied: ipython in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (8.4.0)
# Requirement already satisfied: jupyterlab-server~=2.10 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab>=3->geemap) (2.15.0)
# Requirement already satisfied: plotly>=5.2.2 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from sankee>=0.1.0->geemap) (5.10.0)
# Requirement already satisfied: whitebox in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from whiteboxgui>=0.6.0->geemap) (2.1.4)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from bqplot->geemap) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from pandas->geemap) (2022.1)
# Requirement already satisfied: tqdm in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from gdown->geemap) (4.64.0)
# Requirement already satisfied: filelock in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from gdown->geemap) (3.8.0)
# Requirement already satisfied: ratelim in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: click in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from geocoder->geemap) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from matplotlib->geemap) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from matplotlib->geemap) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from matplotlib->geemap) (4.25.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.3.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (2.8.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.8)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.9.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.1)
# Requirement already satisfied: backcall in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (61.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (3.0.20)
# Requirement already satisfied: colorama in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.4.5)
# Requirement already satisfied: matplotlib-inline in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.1.2)
# Requirement already satisfied: decorator in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipython->jupyterlab>=3->geemap) (5.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.1.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.13.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (3.6.1)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (21.3.0)
# Requirement already satisfied: pywinpty in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (2.0.2)
# Requirement already satisfied: Send2Trash in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (0.13.1)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (5.3.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (23.2.0)
# Requirement already satisfied: websocket-client in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.3.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (7.2.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-core->jupyterlab>=3->geemap) (302)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.4.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.12.0)
# Requirement already satisfied: json5 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.9.9)
# Requirement already satisfied: babel in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (2.10.3)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from notebook<7->jupyterlab>=3->geemap) (1.5.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from plotly>=5.2.2->sankee>=0.1.0->geemap) (8.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from requests->folium>=0.11.0->geemap) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from requests->folium>=0.11.0->geemap) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from requests->folium>=0.11.0->geemap) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.26.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.3)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbclassic->jupyterlab>=3->geemap) (0.1.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.7.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (1.56.4)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (4.21.5)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from importlib-metadata>=3.6->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (3.8.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jedi>=0.16->ipython->jupyterlab>=3->geemap) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (21.4.0)
# Requirement already satisfied: entrypoints in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.4)
# Requirement already satisfied: testpath in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: bleach in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: fastjsonschema in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.15.1)
# Requirement already satisfied: wcwidth in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: executing in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (2.0.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\alemayehu\miniconda3\envs\geo\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3->geemap) (2.21)

# %%
#Import libraries.
import ee
import geemap

# %%
#Authenticate and initialize ee
ee.Authenticate()
ee.Initialize()

# %%
Map = geemap.Map()

#Load countries data
countries = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017");
roi = countries.filter(ee.Filter.eq("country_na","Swaziland"));

landsat = ee.ImageCollection("LANDSAT/LC08/C01/T1") \
    .filterDate('2016-01-01', '2017-01-01') \
    .filterBounds(roi)

composite = ee.Algorithms.Landsat.simpleComposite(**{
  'collection': landsat,
  'asFloat': True
})

rgbVis = {'bands': ["B4", "B3", "B2"], 'min':0, 'max': 0.3}
nirVis = {'bands': ["B5", "B4", "B3"], 'min':0, 'max': [0.5, 0.3, 0.3]}

Map.addLayer(composite.clip(roi), rgbVis, "RGB")
Map.addLayer(composite.clip(roi), nirVis, "False Color")
Map.centerObject(roi, 8)
Map
# Out:
# Map(center=[-26.56458148548865, 31.497700494046793], controls=(WidgetControl(options=['position', 'transparent…

# %%
#Watch more video tutorials
geemap.show_youtube('https://www.youtube.com/playlist?list=PLyJZ14_CYRrCCX6ob4XTzCUJwl2VKl0NL')
